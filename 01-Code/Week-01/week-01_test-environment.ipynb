# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import linalg

print(sys.executable)
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print("Setup check passed.")
# Out:
# D:\OneDrive - lytikz.ai\30_Education\MSc-AI_Linear-Algebra\.venv\Scripts\python.exe
# NumPy: 2.4.2
# Pandas: 3.0.1
# Setup check passed.

# %%
x_values = [0, 1, 2, 3]
y_values = [0, 1, 4, 9]

plt.plot(x_values, y_values)
plt.title("Setup Check Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
