# %% [markdown]
# <style>
# /*
#  * lytikz_Lesson-Stylesheet.css
#  * ─────────────────────────────────────────────────────────────────────────────
#  * Master stylesheet for MSc-AI Linear Algebra lesson notebooks.
#  * Design: Concept A — Refined Warm
#  * Fonts:  Sora (headings) · JetBrains Mono (body, code, labels)
#  * Status: Locked — do not modify without updating Notebook_Design-Spec.md
#  * ─────────────────────────────────────────────────────────────────────────────
#  *
#  * USAGE
#  * Paste the full contents of this file inside a <style> tag in Cell 1 of
#  * every lesson notebook. Do not link externally — DataSpell does not resolve
#  * relative CSS paths in markdown cells.
#  *
#  * DATASPELL RENDERING RULES (summary — full detail in Notebook_Design-Spec.md)
#  *   1. All HTML in markdown cells must be flush left — zero indentation.
#  *   2. Styled cells must be pure HTML — no mixed Markdown syntax.
#  *   3. All prose must be wrapped in <p> tags.
#  *   4. Accent strips must be real child <div> elements — no ::before/::after.
#  *   5. Do not use border-top on the same element as the panel frame.
#  *   6. Use .term not .kt for key term highlighting.
#  *   7. No emojis in any markdown cell — they break rendering entirely.
#  *   8. Panel backgrounds must be opaque (#111110).
#  *   9. Cell 1 is the stylesheet. Cell 2 is the sacrificial header strip.
#  *  10. Left-align panels — do not centre.
#  * ─────────────────────────────────────────────────────────────────────────────
#  */
#
# @import url('https://fonts.googleapis.com/css2?family=Sora:wght@300;400;600;700;800&family=JetBrains+Mono:wght@300;400;500;700&display=swap');
#
# * { box-sizing: border-box; }
#
# /* ── Shell ──────────────────────────────────────────────────────────────────*/
#
# .lesson-shell {
# max-width: 900px;
# margin: 0;
# font-family: 'JetBrains Mono', monospace;
# }
#
# /* ── Header strip (Cell 2 — sacrificial) ────────────────────────────────────*/
#
# .header-strip {
# max-width: 900px;
# padding: 6px 0 6px 36px;
# font-family: 'JetBrains Mono', monospace;
# font-size: 0.50rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# }
#
# .header-strip .brand { color: rgba(196,240,66,0.35); }
# .header-strip .sep   { color: rgba(228,224,218,0.12); margin: 0 10px; }
# .header-strip .meta  { color: rgba(228,224,218,0.12); letter-spacing: 1.5px; }
#
# /* ── Panels ──────────────────────────────────────────────────────────────────*/
#
# .panel {
# position: relative;
# overflow: hidden;
# width: 100%;
# background: #111110;
# border: none;
# border-radius: 6px;
# box-shadow: inset 0 0 0 1px rgba(255,255,255,0.07);
# padding: 36px 44px 40px;
# margin: 0 0 20px 0;
# font-family: 'JetBrains Mono', monospace;
# font-size: 14px;
# line-height: 1.7;
# }
#
# .panel-title { padding: 40px 44px 44px; }
#
# /* ── Accent strips ───────────────────────────────────────────────────────────*/
# /*
#  * Always use a real child <div> — never border-top or ::before.
#  * Green:  Title, Concept, Worked Example panels.
#  * Amber:  AI Connection, Workforce Analytics, Challenge panels.
#  * None:   Orientation/Recap, Reflection, Next Lesson panels.
#  */
#
# .accent-strip {
# position: absolute;
# top: 0; left: 0; right: 0;
# height: 2px;
# }
#
# .accent-green { background: #c4f042; }
# .accent-amber { background: #f0a830; }
#
# /* ── Section row (label + hairline rule) ─────────────────────────────────────*/
#
# .sec-row {
# display: flex;
# align-items: center;
# gap: 18px;
# margin-bottom: 24px;
# padding-bottom: 12px;
# border-bottom: 1px solid rgba(255,255,255,0.05);
# }
#
# .sec-rule {
# flex: 1;
# height: 1px;
# background: rgba(255,255,255,0.05);
# }
#
# .sec-label {
# font-size: 0.50rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# font-weight: 700;
# flex-shrink: 0;
# }
#
# .sec-label.green { color: rgba(196,240,66,0.55); }
# .sec-label.amber { color: rgba(240,168,48,0.55); }
# .sec-label.muted { color: rgba(228,224,218,0.22); }
#
# /* ── Title panel elements ────────────────────────────────────────────────────*/
#
# .wk {
# font-size: 0.52rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(196,240,66,0.55);
# font-weight: 700;
# margin-bottom: 16px;
# }
#
# .lesson-title {
# font-family: 'Sora', sans-serif;
# font-size: 1.90rem;
# font-weight: 700;
# color: #e8e4de;
# line-height: 1.1;
# letter-spacing: -0.02em;
# margin-bottom: 0;
# }
#
# .title-rule {
# width: 48px;
# height: 2px;
# background: #c4f042;
# opacity: 0.40;
# margin-top: 20px;
# }
#
# /* ── Typography ──────────────────────────────────────────────────────────────*/
#
# .panel h3 {
# font-family: 'Sora', sans-serif;
# font-size: 1.10rem;
# font-weight: 600;
# color: #e8e4de;
# line-height: 1.25;
# letter-spacing: -0.01em;
# margin: 0 0 20px 0;
# }
#
# .panel p {
# font-size: 0.80rem;
# color: #c5c0b8;
# line-height: 1.95;
# letter-spacing: 0.01em;
# margin: 0 0 16px 0;
# }
#
# .panel p:last-child { margin-bottom: 0; }
#
# /* ── Key terms ───────────────────────────────────────────────────────────────*/
# /*
#  * Use class="term" — not .kt (DataSpell injects underlines on .kt).
#  * The aggressive selector stack suppresses DataSpell's own styling.
#  */
#
# .term,
# .panel .term,
# .panel strong.term,
# .panel span.term {
# color: #c4f042 !important;
# font-weight: 700 !important;
# text-decoration: none !important;
# border-bottom: none !important;
# box-shadow: none !important;
# background-image: none !important;
# }
#
# /* ── Nested cards ────────────────────────────────────────────────────────────*/
#
# .inner-card {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(240,168,48,0.35);
# background: rgba(240,168,48,0.03);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-note {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(232,69,60,0.35);
# background: rgba(232,69,60,0.025);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-formal {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(196,240,66,0.20);
# background: rgba(196,240,66,0.02);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-card-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(240,168,48,0.55);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-note-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(232,69,60,0.55);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-formal-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(196,240,66,0.40);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-card p,
# .inner-note p,
# .inner-formal p {
# color: #b5b0a8;
# font-size: 0.77rem;
# }
#
# /* ── Inline code ─────────────────────────────────────────────────────────────*/
#
# code.inline {
# background: rgba(196,240,66,0.06);
# color: #c4f042;
# padding: 2px 7px;
# border-radius: 2px;
# font-size: 0.78rem;
# text-decoration: none !important;
# }
#
# /* ── Utilities ───────────────────────────────────────────────────────────────*/
#
# .panel-rule {
# height: 1px;
# background: rgba(255,255,255,0.05);
# margin: 24px 0;
# }
#
# .next-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(228,224,218,0.22);
# font-weight: 700;
# margin-bottom: 10px;
# }
#
# .next-line {
# font-size: 0.75rem;
# color: #8f8a82;
# letter-spacing: 0.01em;
# }
#
# .next-line strong {
# color: #c4f042;
# font-weight: 700;
# }
#
# </style>

# %% [markdown]
# <div class="header-strip">
# <span class="brand">lytikz.ai</span>
# <span class="sep">·</span>
# <span class="meta">MSc AI Preparation</span>
# <span class="sep">·</span>
# <span class="meta">Linear Algebra</span>
# <span class="sep">·</span>
# <span class="meta">12 Week Programme</span>
# </div>

# %% [markdown]
# <div class="lesson-shell">
# <div class="panel panel-title">
# <div class="accent-strip accent-green"></div>
# <div class="wk">Week 4 · Q&amp;A and Consolidation</div>
# <div class="lesson-title">Multiplication Rules, Identity, and Non-Commutativity</div>
# <div class="title-rule"></div>
# </div>
# <div class="panel">
# <div class="sec-row">
# <div class="sec-label muted">How to Use This Session</div>
# <div class="sec-rule"></div>
# </div>
# <p>No new material is introduced here. The purpose of this session is to find out what has genuinely landed from Lessons 1, 2, and 3, and what still needs attention.</p>
# <p>Work through as many questions as I can using the scratch code cell below. Use NumPy to verify calculations. Write interpretation answers as comments in the code cell or as notes alongside the questions. The questions I cannot answer are not failures — they are signals of where to focus going into Week 5.</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Multiplication Mechanics and Shape</div>
# <div class="sec-rule"></div>
# </div>
# <p>Matrix multiplication is not elementwise. Describe in plain English what is actually computed to produce each element of the result matrix. What two things does each element come from, and what operation produces it?</p>
# <p>Matrix A has shape (3, 5) and matrix B has shape (5, 4). Without computing anything, state the shape of AB. Now state what would happen if someone attempted BA and explain why.</p>
# <p>Matrix P has rows <code class="inline">[1, 2, 3]</code> and <code class="inline">[4, 5, 6]</code>. Matrix Q has columns <code class="inline">[1, 0, 0]</code>, <code class="inline">[0, 1, 0]</code>, and <code class="inline">[1, 1, 1]</code>. Without writing any code, compute the element at position (0, 2) of PQ by hand. Show the dot product calculation explicitly.</p>
# <p>A colleague says that matrix multiplication is just a faster way of doing lots of dot products at once. Is that a fair description? What does it capture correctly and what does it miss?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">The Identity Matrix</div>
# <div class="sec-rule"></div>
# </div>
# <p>What is the identity matrix and what property does it have when used in multiplication? Why is it described as the matrix equivalent of the number 1?</p>
# <p>Matrix M has shape (4, 3). Write down the shape of the identity matrix needed to satisfy <code class="inline">M @ I = M</code>. Write down the shape of the identity matrix needed to satisfy <code class="inline">I @ M = M</code>. Are they the same matrix?</p>
# <p>A pipeline produces a combined transformation matrix C. When I check C against the identity, I find they are equal. What does that tell me about the pipeline? Can I conclude that no transformation was applied? Explain your reasoning.</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Transformations and What They Do</div>
# <div class="sec-rule"></div>
# </div>
# <p>In the context of this week, what does it mean to say that a matrix is a transformation? What is it transforming, and how does the shape of the transformation matrix determine what the result looks like?</p>
# <p>An employee vector <code class="inline">[1.2, 0.8]</code> is right-multiplied by the matrix <code class="inline">[[0, 1], [1, 0]]</code>. Compute the result by hand. What has this transformation done to the vector geometrically?</p>
# <p>I apply a transformation to a set of employee vectors and check that the norm of every vector is unchanged before and after. A colleague concludes that the transformation must be a rotation. Are they correct? What additional check is needed and what would it confirm?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-amber"></div>
# <div class="sec-row">
# <div class="sec-label amber">Chaining and Order Dependence</div>
# <div class="sec-rule"></div>
# </div>
# <p>Why can any sequence of linear transformations be collapsed into a single matrix? What property of matrix multiplication makes this possible?</p>
# <p>Transformation A is <code class="inline">[[2, 0], [0, 1]]</code> and transformation B is <code class="inline">[[0, 1], [1, 0]]</code>. Compute AB and BA by hand. Are they equal? What does this tell me about the order of application?</p>
# <p>A people analytics pipeline applies three transformation matrices in sequence: a scaling step, a rotation step, and a projection step. A new analyst applies them in the wrong order. The results look plausible but are numerically different from the correct output. How would I detect this error, and what would I check to diagnose it?</p>
# <p>Neural networks are sometimes described as a sequence of matrix multiplications. If that were the complete picture, why would adding more layers accomplish nothing? What breaks that collapse in practice, and why does it matter?</p>
# </div>
# </div>

# %%
import numpy as np

# ── Multiplication Mechanics and Shape ────────────────────────────────────────
P = np.array([[1, 2, 3], [4, 5, 6]], dtype = float)
Q = np.array([[1, 0, 1], [0, 1, 1], [0, 0, 1]], dtype = float)

# TODO: compute P @ Q and confirm element [0, 2] matches your hand calculation


# ── The Identity Matrix ───────────────────────────────────────────────────────
M = np.random.rand(4, 3)

# TODO: construct the correct identity matrices for M @ I and I @ M
# and confirm both return M unchanged


# ── Transformations and What They Do ──────────────────────────────────────────
v    = np.array([[1.2, 0.8]], dtype = float)
swap = np.array([[0, 1], [1, 0]], dtype = float)

# TODO: apply the transformation and confirm the result matches your hand calculation


# ── Chaining and Order Dependence ─────────────────────────────────────────────
calc_a = np.array([[2, 0], [0, 1]], dtype = float)
calc_b = np.array([[0, 1], [1, 0]], dtype = float)

# TODO: compute calc_a @ calc_b and calc_b @ calc_a and confirm whether they are equal

# %% [markdown]
# <div class="lesson-shell">
# <div class="panel">
# <div class="sec-row">
# <div class="sec-label muted">My Reflection</div>
# <div class="sec-rule"></div>
# </div>
# <p>Before moving on to Week 5, take stock of the full Week 4 arc without looking at any notes. Can I explain in plain English what matrix multiplication is doing at each step, including why the shape rule holds? Can I describe what a transformation matrix does to a set of vectors, and how to classify a transformation as a rotation versus a reflection? And can I explain why any chain of linear transformations collapses to a single matrix, and why order matters when it does?</p>
# <p>Which questions in this session exposed a gap? What will I do differently in Week 5 to close it?</p>
# <div class="panel-rule"></div>
# <div class="next-label">Next Week</div>
# <div class="next-line"><strong>Week 5, Lesson 1:</strong> Systems of Linear Equations — matrix multiplication becomes the language for representing and solving systems of constraints, from workforce planning problems to optimisation models.</div>
# </div>
# </div>
