# %% [markdown]
# <style>
# /*
#  * lytikz_Lesson-Stylesheet.css
#  * ─────────────────────────────────────────────────────────────────────────────
#  * Master stylesheet for MSc-AI Linear Algebra lesson notebooks.
#  * Design: Concept A — Refined Warm
#  * Fonts:  Sora (headings) · JetBrains Mono (body, code, labels)
#  * Status: Locked — do not modify without updating Notebook_Design-Spec.md
#  * ─────────────────────────────────────────────────────────────────────────────
#  *
#  * USAGE
#  * Paste the full contents of this file inside a <style> tag in Cell 1 of
#  * every lesson notebook. Do not link externally — DataSpell does not resolve
#  * relative CSS paths in markdown cells.
#  *
#  * DATASPELL RENDERING RULES (summary — full detail in Notebook_Design-Spec.md)
#  *   1. All HTML in markdown cells must be flush left — zero indentation.
#  *   2. Styled cells must be pure HTML — no mixed Markdown syntax.
#  *   3. All prose must be wrapped in <p> tags.
#  *   4. Accent strips must be real child <div> elements — no ::before/::after.
#  *   5. Do not use border-top on the same element as the panel frame.
#  *   6. Use .term not .kt for key term highlighting.
#  *   7. No emojis in any markdown cell — they break rendering entirely.
#  *   8. Panel backgrounds must be opaque (#111110).
#  *   9. Cell 1 is the stylesheet. Cell 2 is the sacrificial header strip.
#  *  10. Left-align panels — do not centre.
#  * ─────────────────────────────────────────────────────────────────────────────
#  */
#
# @import url('https://fonts.googleapis.com/css2?family=Sora:wght@300;400;600;700;800&family=JetBrains+Mono:wght@300;400;500;700&display=swap');
#
# * { box-sizing: border-box; }
#
# /* ── Shell ──────────────────────────────────────────────────────────────────*/
#
# .lesson-shell {
# max-width: 900px;
# margin: 0;
# font-family: 'JetBrains Mono', monospace;
# }
#
# /* ── Header strip (Cell 2 — sacrificial) ────────────────────────────────────*/
#
# .header-strip {
# max-width: 900px;
# padding: 6px 0 6px 36px;
# font-family: 'JetBrains Mono', monospace;
# font-size: 0.50rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# }
#
# .header-strip .brand { color: rgba(196,240,66,0.35); }
# .header-strip .sep   { color: rgba(228,224,218,0.12); margin: 0 10px; }
# .header-strip .meta  { color: rgba(228,224,218,0.12); letter-spacing: 1.5px; }
#
# /* ── Panels ──────────────────────────────────────────────────────────────────*/
#
# .panel {
# position: relative;
# overflow: hidden;
# width: 100%;
# background: #111110;
# border: none;
# border-radius: 6px;
# box-shadow: inset 0 0 0 1px rgba(255,255,255,0.07);
# padding: 36px 44px 40px;
# margin: 0 0 20px 0;
# font-family: 'JetBrains Mono', monospace;
# font-size: 14px;
# line-height: 1.7;
# }
#
# .panel-title { padding: 40px 44px 44px; }
#
# /* ── Accent strips ───────────────────────────────────────────────────────────*/
# /*
#  * Always use a real child <div> — never border-top or ::before.
#  * Green:  Title, Concept, Worked Example panels.
#  * Amber:  AI Connection, Workforce Analytics, Challenge panels.
#  * None:   Orientation/Recap, Reflection, Next Lesson panels.
#  */
#
# .accent-strip {
# position: absolute;
# top: 0; left: 0; right: 0;
# height: 2px;
# }
#
# .accent-green { background: #c4f042; }
# .accent-amber { background: #f0a830; }
#
# /* ── Section row (label + hairline rule) ─────────────────────────────────────*/
#
# .sec-row {
# display: flex;
# align-items: center;
# gap: 18px;
# margin-bottom: 24px;
# padding-bottom: 12px;
# border-bottom: 1px solid rgba(255,255,255,0.05);
# }
#
# .sec-rule {
# flex: 1;
# height: 1px;
# background: rgba(255,255,255,0.05);
# }
#
# .sec-label {
# font-size: 0.50rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# font-weight: 700;
# flex-shrink: 0;
# }
#
# .sec-label.green { color: rgba(196,240,66,0.55); }
# .sec-label.amber { color: rgba(240,168,48,0.55); }
# .sec-label.muted { color: rgba(228,224,218,0.22); }
#
# /* ── Title panel elements ────────────────────────────────────────────────────*/
#
# .wk {
# font-size: 0.52rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(196,240,66,0.55);
# font-weight: 700;
# margin-bottom: 16px;
# }
#
# .lesson-title {
# font-family: 'Sora', sans-serif;
# font-size: 1.90rem;
# font-weight: 700;
# color: #e8e4de;
# line-height: 1.1;
# letter-spacing: -0.02em;
# margin-bottom: 0;
# }
#
# .title-rule {
# width: 48px;
# height: 2px;
# background: #c4f042;
# opacity: 0.40;
# margin-top: 20px;
# }
#
# /* ── Typography ──────────────────────────────────────────────────────────────*/
#
# .panel h3 {
# font-family: 'Sora', sans-serif;
# font-size: 1.10rem;
# font-weight: 600;
# color: #e8e4de;
# line-height: 1.25;
# letter-spacing: -0.01em;
# margin: 0 0 20px 0;
# }
#
# .panel p {
# font-size: 0.80rem;
# color: #c5c0b8;
# line-height: 1.95;
# letter-spacing: 0.01em;
# margin: 0 0 16px 0;
# }
#
# .panel p:last-child { margin-bottom: 0; }
#
# /* ── Key terms ───────────────────────────────────────────────────────────────*/
# /*
#  * Use class="term" — not .kt (DataSpell injects underlines on .kt).
#  * The aggressive selector stack suppresses DataSpell's own styling.
#  */
#
# .term,
# .panel .term,
# .panel strong.term,
# .panel span.term {
# color: #c4f042 !important;
# font-weight: 700 !important;
# text-decoration: none !important;
# border-bottom: none !important;
# box-shadow: none !important;
# background-image: none !important;
# }
#
# /* ── Nested cards ────────────────────────────────────────────────────────────*/
#
# .inner-card {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(240,168,48,0.35);
# background: rgba(240,168,48,0.03);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-note {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(232,69,60,0.35);
# background: rgba(232,69,60,0.025);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-formal {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(196,240,66,0.20);
# background: rgba(196,240,66,0.02);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-card-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(240,168,48,0.55);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-note-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(232,69,60,0.55);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-formal-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(196,240,66,0.40);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-card p,
# .inner-note p,
# .inner-formal p {
# color: #b5b0a8;
# font-size: 0.77rem;
# }
#
# /* ── Inline code ─────────────────────────────────────────────────────────────*/
#
# code.inline {
# background: rgba(196,240,66,0.06);
# color: #c4f042;
# padding: 2px 7px;
# border-radius: 2px;
# font-size: 0.78rem;
# text-decoration: none !important;
# }
#
# /* ── Utilities ───────────────────────────────────────────────────────────────*/
#
# .panel-rule {
# height: 1px;
# background: rgba(255,255,255,0.05);
# margin: 24px 0;
# }
#
# .next-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(228,224,218,0.22);
# font-weight: 700;
# margin-bottom: 10px;
# }
#
# .next-line {
# font-size: 0.75rem;
# color: #8f8a82;
# letter-spacing: 0.01em;
# }
#
# .next-line strong {
# color: #c4f042;
# font-weight: 700;
# }
#
# </style>

# %% [markdown]
# <div class="header-strip">
# <span class="brand">lytikz.ai</span>
# <span class="sep">·</span>
# <span class="meta">MSc AI Preparation</span>
# <span class="sep">·</span>
# <span class="meta">Linear Algebra</span>
# <span class="sep">·</span>
# <span class="meta">12 Week Programme</span>
# </div>

# %% [markdown]
# <div class="lesson-shell">
# <div class="panel panel-title">
# <div class="accent-strip accent-green"></div>
# <div class="wk">Week 3 · Q&amp;A and Consolidation</div>
# <div class="lesson-title">Matrix Structure, Operations, and Transpose</div>
# <div class="title-rule"></div>
# </div>
# <div class="panel">
# <div class="sec-row">
# <div class="sec-label muted">How to Use This Session</div>
# <div class="sec-rule"></div>
# </div>
# <p>No new material is introduced here. The purpose of this session is to find out what has genuinely landed from Lessons 1, 2, and 3, and what still needs attention.</p>
# <p>Work through as many questions as I can using the scratch code cell below. Use NumPy to verify calculations. Write interpretation answers as comments in the code cell or as notes alongside the questions. The questions I cannot answer are not failures. They are signals of where to focus going into Week 4.</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Matrix Structure and Navigation</div>
# <div class="sec-rule"></div>
# </div>
# <p>What is the difference between a matrix and a vector? Under what conditions is a vector also a matrix?</p>
# <p>A colleague says a dataset has shape (120, 6). Without looking at the data, what can I say immediately about its structure? What does each dimension represent in a typical workforce context?</p>
# <p>Given a matrix A, what is the difference between writing <code class="inline">A[2]</code> and <code class="inline">A[:, 2]</code> in NumPy? What does each return, and what would each tell me in a workforce context?</p>
# <p>In mathematical notation, the element A<sub>23</sub> refers to a specific position. What is that position, and how would I access the same element in NumPy? Why do the two answers differ?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Operations and Meaning</div>
# <div class="sec-rule"></div>
# </div>
# <p>Matrix addition requires shape compatibility. What does that mean exactly, and why is matching shape alone not always sufficient to make the result analytically meaningful?</p>
# <p>Given the following two matrices, compute A + B by hand. What is the shape of the result? Check one element of your answer by tracing through the elementwise rule explicitly.</p>
# <p>A = <code class="inline">[[4, 2], [1, 7], [5, 3]]</code></p>
# <p>B = <code class="inline">[[3, 6], [2, 0], [1, 4]]</code></p>
# <p>A headcount table has shape (5, 3). After multiplying by a scalar of 1.20, what is the shape of the result and what has happened to each element?</p>
# <p>I multiply a combined headcount table by 0.80 and present the output to a senior leader. They ask: "Is this what headcount will look like next year?" What is the honest answer, and what should I tell them about what the output does and does not represent?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Transpose and Reorientation</div>
# <div class="sec-rule"></div>
# </div>
# <p>Transpose changes the orientation of a matrix but not its values. What does that mean in practice? Give an example using a workforce dataset where the transposed orientation would be more natural than the original.</p>
# <p>The transpose of a matrix <strong>A</strong> is defined by the rule (<strong>A</strong><sup>T</sup>)<sub>ij</sub> = A<sub>ji</sub>. In plain English, what is that rule saying?</p>
# <p>Matrix C has the following values: <code class="inline">[[10, 20, 15], [8, 12, 9]]</code>. Write out C<sup>T</sup> by hand. Confirm the shape of the result. Then identify the value at position (C<sup>T</sup>)<sub>32</sub>, using standard mathematical row-column indexing, and trace it back to its original position in C.</p>
# <p>I have an employee-by-attribute matrix with shape (200, 8). A colleague needs the data in attribute-by-employee orientation. What operation do I apply, what will the new shape be, and what has changed in the data?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-amber"></div>
# <div class="sec-row">
# <div class="sec-label amber">Before Week 4</div>
# <div class="sec-rule"></div>
# </div>
# <p>Transpose appears inside the normal equation for linear regression and inside backpropagation in neural networks. Without knowing the details of those operations yet, what does that suggest about why transpose matters beyond simple data reshaping?</p>
# <p>Across the three lessons this week I have learned to build a matrix, navigate it, add two matrices, multiply by a scalar, and transpose. If someone asked me to summarise what a matrix is in two sentences and name the single most important rule I have learned about operating on one, what would I say?</p>
# </div>
# </div>

# %%
import numpy as np

# ── Matrix structure and navigation ───────────────────────────────────────────
# Write conceptual answers or quick checks here.


# ── Operations and meaning ────────────────────────────────────────────────────
A = np.array([
    [4, 2],
    [1, 7],
    [5, 3],
], dtype = float)

B = np.array([
    [3, 6],
    [2, 0],
    [1, 4],
], dtype = float)

# TODO: compute A + B and verify shape
# TODO: check one element of A + B against the elementwise rule
# TODO: verify scalar multiplication shape and elementwise effect

# ── Transpose and reorientation ───────────────────────────────────────────────
C = np.array([
    [10, 20, 15],
    [ 8, 12,  9],
], dtype = float)

# TODO: compute C.T, verify shape, identify element at mathematical position (3,2)

# ── Before Week 4 ─────────────────────────────────────────────────────────────
# Write synthesis notes or remaining questions here.

# %% [markdown]
# <div class="lesson-shell">
# <div class="panel">
# <div class="sec-row">
# <div class="sec-label muted">My Reflection</div>
# <div class="sec-rule"></div>
# </div>
# <p>Looking back across Lessons 1, 2, and 3: what was the single idea that shifted my understanding the most, and what question do I still want answered going into Week 4?</p>
# <p>Which questions in this session exposed a gap? The ones most likely to surface one are the transpose element-tracing question and the scalar multiplication interpretation question. If either felt uncertain, return to Lesson 2 or Lesson 3 before continuing.</p>
# <div class="panel-rule"></div>
# <div class="next-label">Next Week</div>
# <div class="next-line"><strong>Week 4, Lesson 1:</strong> Matrix Multiplication. The most important matrix operation of all, and the foundation for understanding how neural networks process data.</div>
# </div>
# </div>
