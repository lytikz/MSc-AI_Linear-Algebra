# %% [markdown]
# <style>
# /*
#  * lytikz_Lesson-Stylesheet.css
#  * ─────────────────────────────────────────────────────────────────────────────
#  * Master stylesheet for MSc-AI Linear Algebra lesson notebooks.
#  * Design: Concept A — Refined Warm
#  * Fonts:  Sora (headings) · JetBrains Mono (body, code, labels)
#  * Status: Locked — do not modify without updating Notebook_Design-Spec.md
#  * ─────────────────────────────────────────────────────────────────────────────
#  *
#  * USAGE
#  * Paste the full contents of this file inside a <style> tag in Cell 1 of
#  * every lesson notebook. Do not link externally — DataSpell does not resolve
#  * relative CSS paths in markdown cells.
#  *
#  * DATASPELL RENDERING RULES (summary — full detail in Notebook_Design-Spec.md)
#  *   1. All HTML in markdown cells must be flush left — zero indentation.
#  *   2. Styled cells must be pure HTML — no mixed Markdown syntax.
#  *   3. All prose must be wrapped in <p> tags.
#  *   4. Accent strips must be real child <div> elements — no ::before/::after.
#  *   5. Do not use border-top on the same element as the panel frame.
#  *   6. Use .term not .kt for key term highlighting.
#  *   7. No emojis in any markdown cell — they break rendering entirely.
#  *   8. Panel backgrounds must be opaque (#111110).
#  *   9. Cell 1 is the stylesheet. Cell 2 is the sacrificial header strip.
#  *  10. Left-align panels — do not centre.
#  * ─────────────────────────────────────────────────────────────────────────────
#  */
#
# @import url('https://fonts.googleapis.com/css2?family=Sora:wght@300;400;600;700;800&family=JetBrains+Mono:wght@300;400;500;700&display=swap');
#
# * { box-sizing: border-box; }
#
# /* ── Shell ──────────────────────────────────────────────────────────────────*/
#
# .lesson-shell {
# max-width: 900px;
# margin: 0;
# font-family: 'JetBrains Mono', monospace;
# }
#
# /* ── Header strip (Cell 2 — sacrificial) ────────────────────────────────────*/
#
# .header-strip {
# max-width: 900px;
# padding: 6px 0 6px 36px;
# font-family: 'JetBrains Mono', monospace;
# font-size: 0.50rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# }
#
# .header-strip .brand { color: rgba(196,240,66,0.35); }
# .header-strip .sep   { color: rgba(228,224,218,0.12); margin: 0 10px; }
# .header-strip .meta  { color: rgba(228,224,218,0.12); letter-spacing: 1.5px; }
#
# /* ── Panels ──────────────────────────────────────────────────────────────────*/
#
# .panel {
# position: relative;
# overflow: hidden;
# width: 100%;
# background: #111110;
# border: none;
# border-radius: 6px;
# box-shadow: inset 0 0 0 1px rgba(255,255,255,0.07);
# padding: 36px 44px 40px;
# margin: 0 0 20px 0;
# font-family: 'JetBrains Mono', monospace;
# font-size: 14px;
# line-height: 1.7;
# }
#
# .panel-title { padding: 40px 44px 44px; }
#
# /* ── Accent strips ───────────────────────────────────────────────────────────*/
# /*
#  * Always use a real child <div> — never border-top or ::before.
#  * Green:  Title, Concept, Worked Example panels.
#  * Amber:  AI Connection, Workforce Analytics, Challenge panels.
#  * None:   Orientation/Recap, Reflection, Next Lesson panels.
#  */
#
# .accent-strip {
# position: absolute;
# top: 0; left: 0; right: 0;
# height: 2px;
# }
#
# .accent-green { background: #c4f042; }
# .accent-amber { background: #f0a830; }
#
# /* ── Section row (label + hairline rule) ─────────────────────────────────────*/
#
# .sec-row {
# display: flex;
# align-items: center;
# gap: 18px;
# margin-bottom: 24px;
# padding-bottom: 12px;
# border-bottom: 1px solid rgba(255,255,255,0.05);
# }
#
# .sec-rule {
# flex: 1;
# height: 1px;
# background: rgba(255,255,255,0.05);
# }
#
# .sec-label {
# font-size: 0.50rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# font-weight: 700;
# flex-shrink: 0;
# }
#
# .sec-label.green { color: rgba(196,240,66,0.55); }
# .sec-label.amber { color: rgba(240,168,48,0.55); }
# .sec-label.muted { color: rgba(228,224,218,0.22); }
#
# /* ── Title panel elements ────────────────────────────────────────────────────*/
#
# .wk {
# font-size: 0.52rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(196,240,66,0.55);
# font-weight: 700;
# margin-bottom: 16px;
# }
#
# .lesson-title {
# font-family: 'Sora', sans-serif;
# font-size: 1.90rem;
# font-weight: 700;
# color: #e8e4de;
# line-height: 1.1;
# letter-spacing: -0.02em;
# margin-bottom: 0;
# }
#
# .title-rule {
# width: 48px;
# height: 2px;
# background: #c4f042;
# opacity: 0.40;
# margin-top: 20px;
# }
#
# /* ── Typography ──────────────────────────────────────────────────────────────*/
#
# .panel h3 {
# font-family: 'Sora', sans-serif;
# font-size: 1.10rem;
# font-weight: 600;
# color: #e8e4de;
# line-height: 1.25;
# letter-spacing: -0.01em;
# margin: 0 0 20px 0;
# }
#
# .panel p {
# font-size: 0.80rem;
# color: #c5c0b8;
# line-height: 1.95;
# letter-spacing: 0.01em;
# margin: 0 0 16px 0;
# }
#
# .panel p:last-child { margin-bottom: 0; }
#
# /* ── Key terms ───────────────────────────────────────────────────────────────*/
# /*
#  * Use class="term" — not .kt (DataSpell injects underlines on .kt).
#  * The aggressive selector stack suppresses DataSpell's own styling.
#  */
#
# .term,
# .panel .term,
# .panel strong.term,
# .panel span.term {
# color: #c4f042 !important;
# font-weight: 700 !important;
# text-decoration: none !important;
# border-bottom: none !important;
# box-shadow: none !important;
# background-image: none !important;
# }
#
# /* ── Nested cards ────────────────────────────────────────────────────────────*/
#
# .inner-card {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(240,168,48,0.35);
# background: rgba(240,168,48,0.03);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-note {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(232,69,60,0.35);
# background: rgba(232,69,60,0.025);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-formal {
# margin: 24px 0;
# padding: 22px 28px;
# border-left: 2px solid rgba(196,240,66,0.20);
# background: rgba(196,240,66,0.02);
# border-radius: 0 4px 4px 0;
# }
#
# .inner-card-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(240,168,48,0.55);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-note-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(232,69,60,0.55);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-formal-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(196,240,66,0.40);
# margin-bottom: 12px;
# font-weight: 700;
# }
#
# .inner-card p,
# .inner-note p,
# .inner-formal p {
# color: #b5b0a8;
# font-size: 0.77rem;
# }
#
# /* ── Inline code ─────────────────────────────────────────────────────────────*/
#
# code.inline {
# background: rgba(196,240,66,0.06);
# color: #c4f042;
# padding: 2px 7px;
# border-radius: 2px;
# font-size: 0.78rem;
# text-decoration: none !important;
# }
#
# /* ── Utilities ───────────────────────────────────────────────────────────────*/
#
# .panel-rule {
# height: 1px;
# background: rgba(255,255,255,0.05);
# margin: 24px 0;
# }
#
# .next-label {
# font-size: 0.46rem;
# letter-spacing: 2.5px;
# text-transform: uppercase;
# color: rgba(228,224,218,0.22);
# font-weight: 700;
# margin-bottom: 10px;
# }
#
# .next-line {
# font-size: 0.75rem;
# color: #8f8a82;
# letter-spacing: 0.01em;
# }
#
# .next-line strong {
# color: #c4f042;
# font-weight: 700;
# }
#
# </style>

# %% [markdown]
# <div class="header-strip">
# <span class="brand">lytikz.ai</span>
# <span class="sep">·</span>
# <span class="meta">MSc AI Preparation</span>
# <span class="sep">·</span>
# <span class="meta">Linear Algebra</span>
# <span class="sep">·</span>
# <span class="meta">12 Week Programme</span>
# </div>

# %% [markdown]
# <div class="lesson-shell">
# <div class="panel panel-title">
# <div class="accent-strip accent-green"></div>
# <div class="wk">Week 2 · Q&amp;A and Consolidation</div>
# <div class="lesson-title">Operations, Magnitude, Distance, and Normalisation</div>
# <div class="title-rule"></div>
# </div>
# <div class="panel">
# <div class="sec-row">
# <div class="sec-label muted">How to Use This Session</div>
# <div class="sec-rule"></div>
# </div>
# <p>No new material is introduced here. The purpose of this session is to find out what has genuinely landed from Lessons 1, 2, and 3, and what still needs attention.</p>
# <p>Work through as many questions as I can using the scratch code cell below. Use NumPy to verify calculations. Write interpretation answers as comments in the code cell or as notes alongside the questions. The questions I cannot answer are not failures — they are signals of where to focus going into Week 3.</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Operations on Vectors</div>
# <div class="sec-rule"></div>
# </div>
# <p>What is the difference between <span class="term">scalar multiplication</span> and <span class="term">vector addition</span> in plain English? Give one example of each from a people analytics context.</p>
# <p>I multiply an employee profile vector <span class="term">[34, 5, 72, 4]</span> by 0.5. Is the result still a meaningful employee profile? What question do I need to ask before treating any scaled vector as interpretable?</p>
# <p>What is a <span class="term">linear combination</span>? Without using a formula, explain why it sits at the centre of how neural networks work.</p>
# <p>Given <strong>a</strong> = [3, 0, 4] and scalar <span class="term">c = 3</span>, compute <span class="term">c * a</span> by hand. What is the magnitude of the result, and how does it relate to the magnitude of <strong>a</strong>?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Distance and Comparison</div>
# <div class="sec-rule"></div>
# </div>
# <p>What does <span class="term">Euclidean distance</span> measure that cosine similarity does not? Explain the distinction using the idea of direction versus separation.</p>
# <p>Given <span class="term">calc_a = [2, 5, 1]</span> and <span class="term">calc_b = [4, 1, 3]</span>, compute the difference vector <span class="term">calc_a &#8722; calc_b</span> by hand. Then compute the Euclidean distance. Verify both with NumPy.</p>
# <p>I compute the Euclidean distance between two employee profiles on raw values and get 28.3. After min-max normalisation using organisational bounds, the distance drops to 0.21. What does that tell me about which dimension was dominating the raw distance, and why does the normalised distance give a better picture?</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-green"></div>
# <div class="sec-row">
# <div class="sec-label green">Normalisation and Weighting</div>
# <div class="sec-rule"></div>
# </div>
# <p>What is the difference between <span class="term">min-max normalisation</span> and <span class="term">unit vector normalisation</span>? When would I use one rather than the other?</p>
# <p>A dimension has a raw value of 65, a minimum of 0, and a maximum of 100. What is its min-max normalised value? Now apply a weight of 0.3. What is the weighted contribution of this dimension to a composite score?</p>
# <p>Given two normalised employee profiles <span class="term">p = [0.35, 0.20, 0.70, 0.75]</span> and <span class="term">q = [0.50, 0.60, 0.55, 0.50]</span> and weights <span class="term">w = [0.1, 0.2, 0.3, 0.4]</span>, compute the composite score for each employee and the weighted Euclidean distance between them.</p>
# <p>Two candidates have weighted composite scores of 0.71 and 0.68. A colleague says the first candidate is clearly stronger. What would I want to know before accepting that conclusion?</p>
# <p>I have three employee profiles after min-max normalisation. Employee X scores 0.82 on a composite model. Employee Y scores 0.44. Their Euclidean distance is 0.39 but their cosine similarity is 0.97. Write two sentences explaining what this combination of results tells a people analytics team about these two employees.</p>
# </div>
# <div class="panel">
# <div class="accent-strip accent-amber"></div>
# <div class="sec-row">
# <div class="sec-label amber">Before Week 3</div>
# <div class="sec-rule"></div>
# </div>
# <p>Normalisation is described as a prerequisite rather than an option in machine learning pipelines. In one sentence, explain why failing to normalise input features before training a neural network is a problem — and what the network cannot correct for on its own.</p>
# <p>In a real workforce analytics workflow, where might weighting and normalisation decisions be made implicitly rather than explicitly? What is the risk of leaving those decisions unexamined?</p>
# </div>
# </div>

# %%
import numpy as np

# ── Operations on Vectors ──────────────────────────────────────────────────────
a      = np.array([3, 0, 4], dtype = float)
c      = 3

# TODO: scalar multiplication c * a, magnitude before and after

# ── Distance and Comparison ────────────────────────────────────────────────────
calc_a = np.array([2, 5, 1], dtype = float)
calc_b = np.array([4, 1, 3], dtype = float)

# TODO: difference vector calc_a - calc_b, Euclidean distance

# ── Normalisation and Weighting ────────────────────────────────────────────────
p = np.array([0.35, 0.20, 0.70, 0.75], dtype = float)
q = np.array([0.50, 0.60, 0.55, 0.50], dtype = float)
w = np.array([0.10, 0.20, 0.30, 0.40], dtype = float)

# TODO: min-max normalisation of value 65 in range 0-100, weighted contribution
# TODO: composite scores for p and q, weighted Euclidean distance

# ── Before Week 3 ─────────────────────────────────────────────────────────────
# Write synthesis notes or remaining questions here.

# %% [markdown]
# <div class="lesson-shell">
# <div class="panel">
# <div class="sec-row">
# <div class="sec-label muted">My Reflection</div>
# <div class="sec-rule"></div>
# </div>
# <p>Looking back across Lessons 1, 2, and 3: what was the single idea that shifted my understanding the most, and what question do I still want answered going into Week 3?</p>
# <p>Which questions in this session exposed a gap? What will I do differently in Week 3 to close it?</p>
# <div class="panel-rule"></div>
# <div class="next-label">Next Week</div>
# <div class="next-line"><strong>Week 3, Lesson 1:</strong> From Vectors to Matrices — representing an entire workforce dataset as a single structured object.</div>
# </div>
# </div>
